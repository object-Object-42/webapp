# %%
from sqlmodel import Field, SQLModel, create_engine, Session, select

# %%
engine = create_engine(
    url="postgresql+psycopg://postgres:changethis@localhost:5432/app", echo=True
)

# %%
import psycopg

conn = psycopg.connect(
    host="localhost:5432", database="app", user="postgres", password="changethis"
)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[14], line 3
#       1 import psycopg
# ----> 3 conn = psycopg.connect(
#       4     host="localhost:5432", dbname="app", user="postgres", password="changethis"
#       5 )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/fastapi/lib/python3.12/site-packages/psycopg/connection.py:98, in Connection.connect(cls, conninfo, autocommit, prepare_threshold, context, row_factory, cursor_factory, **kwargs)
#      96 timeout = timeout_from_conninfo(params)
#      97 rv = None
# ---> 98 attempts = conninfo_attempts(params)
#      99 for attempt in attempts:
#     100     try:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/fastapi/lib/python3.12/site-packages/psycopg/_conninfo_attempts.py:50, in conninfo_attempts(params)
#      48     assert last_exc
#      49     # We couldn't resolve anything
# ...

# %%
from sqlalchemy import create_engine, MetaData, Table, select

# Create an engine instance
engine = create_engine(
    "postgresql+psycopg://postgres:changethis@localhost:5432/app", echo=True
)

# Connect to the database
connection = engine.connect()

# Perform database operations here
# Define metadata and reflect the existing database schema
metadata = MetaData()
metadata.reflect(bind=engine)

# Define the content table
content_table = Table("content", metadata, autoload_with=engine)

# Create a select statement to query the table
stmt = select(content_table)

# Execute the query and fetch the results
results = connection.execute(stmt).fetchmany(size=25)

# Print the results
# for row in results:
#     print(row)

# Close the connection
# connection.close()
# Out:
# 2024-10-26 21:29:24,859 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2024-10-26 21:29:24,860 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-10-26 21:29:24,862 INFO sqlalchemy.engine.Engine select current_schema()
# 2024-10-26 21:29:24,878 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-10-26 21:29:24,885 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2024-10-26 21:29:24,892 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-10-26 21:29:24,921 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-26 21:29:24,922 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# ...

# %%
print(results[0][0])
print(results[0][1])
# Out:
# WLAN (eduroam) [doku.rz.hs-fulda.de]
# Dokumentation des Rechenzentrums \[doku.rz.hs\-fulda.de]
# [![Rechenzentrum](/lib/exe/fetch.php/logo.png)Rechenzentrum](/doku.php/start "Rechenzentrum")
# * [Anmelden](/doku.php/docs:start?do=login&sectok= "Anmelden")
# * Inhaltsverzeichnis
# 	+ Inhaltsverzeichnis
#  Seitenleiste
# ##### Dokumentation
# * [Backup](/doku.php/docs:backup "docs:backup")
# * [Benutzeraccount (fd\-Nummer)](/doku.php/docs:benutzeraccount "docs:benutzeraccount")
# * [Datenanalyse\-Tools](/doku.php/docs:datenanalyse-tools "docs:datenanalyse-tools")
# * [DFN\-AAI](/doku.php/docs:dfn-aai "docs:dfn-aai")
# * [DFN\-CERT Portal](/doku.php/docs:dfncert "docs:dfncert")
# * [Domain Name Service (DNS)](/doku.php/docs:nameserver "docs:nameserver")
# * [E\-Mail und Groupware](/doku.php/docs:email:start "docs:email:start")
# * [Hessenbox (Sync \& Share)](/doku.php/docs:hessenbox "docs:hessenbox")
# * [horstl](/doku.php/docs:horstl "docs:horstl")
# ...

# %%
print(len(results))

length = 0
for row in results:
    length += len(row[1])
    # print(row[0])

print(length)
# Out:
# 25
# 215137

# %%
from context import fetch_content

results = fetch_content()
print(results)
# Out:
# 2024-10-26 21:42:20,698 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2024-10-26 21:42:20,700 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-10-26 21:42:20,707 INFO sqlalchemy.engine.Engine select current_schema()
# 2024-10-26 21:42:20,710 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-10-26 21:42:20,716 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2024-10-26 21:42:20,718 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2024-10-26 21:42:20,734 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-10-26 21:42:20,735 INFO sqlalchemy.engine.Engine SELECT pg_catalog.pg_class.relname
# FROM pg_catalog.pg_class JOIN pg_catalog.pg_namespace ON pg_catalog.pg_namespace.oid = pg_catalog.pg_class.relnamespace
# ...
